# %%
import pandas as pd
df = pd.read_csv('/Users/suryabhosale/Documents/projects/DORIS/src/dorisclinicaltrials/ct_csv/CT_CSV_17_05.csv')
df
# Out:
#       Unnamed: 0.1  Unnamed: 0   NCT_NUMBER  \
# 0                0           0  NCT03275311
# 1                1           1  NCT06150898
# 2                2           2  NCT06214793
# 3                3           3  NCT05496101
# 4                4           4  NCT05935384
# ...            ...         ...          ...
# 2524          2524        2524  NCT06327490
# 2525          2525        2525  NCT04314401
# 2526          2526        2526  NCT04472845
# 2527          2527        2527  NCT05536128
# 2528          2528        2528  NCT05403554
#
#                                             STUDY_TITLE  \
# 0     Evolution of the Therapeutic Care in Metastati...
# 1     Ketorolac and Pregabalin Effects on breaSt Can...
# 2     Taletrectinib in Previously Treated Metastatic...
# 3      CLI and FAR for Intraoperative Margin Assessment
# 4     SIBYL: obServation of Therapy Response With lI...
# ...                                                 ...
# ...

# %%
def get_zip_list(row):
    zip_list = []
    for loc_item in row:
        if loc_item['Location Zip']:
            zip_list.append(loc_item['Location Zip'])
    zip_str = ' '.join(zip_list)
    return zip_str

# %%
df['ZIP_STR'] = df.LOCATIONS.apply(lambda x: get_zip_list(x))
df['ZIP_STR']
# Out:
# 0       49933 33076 14076 63011 21079 59020 69373 1327...
# 1                                                    1170
# 2                                             33331 44195
# 3                                                  SE19RT
# 4                                              60077-1384
#                               ...
# 2524                                                32610
# 2525    86401 72903 93420 19901 19963 30342 31405 6170...
# 2526                                               160012
# 2527
# 2528                  75005 75015 35042 20089 20141 37134
# Name: ZIP_STR, Length: 2529, dtype: object

# %%
df.to_csv('../ct_csv/CT_CSV_22_05.csv')

# %%
df = pd.read_csv('../ct_csv/CT_CSV_22_05.csv')
df
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0   NCT_NUMBER  \
# 0                0             0           0  NCT03275311
# 1                1             1           1  NCT06150898
# 2                2             2           2  NCT06214793
# 3                3             3           3  NCT05496101
# 4                4             4           4  NCT05935384
# ...            ...           ...         ...          ...
# 2524          2524          2524        2524  NCT06327490
# 2525          2525          2525        2525  NCT04314401
# 2526          2526          2526        2526  NCT04472845
# 2527          2527          2527        2527  NCT05536128
# 2528          2528          2528        2528  NCT05403554
#
#                                             STUDY_TITLE  \
# 0     Evolution of the Therapeutic Care in Metastati...
# 1     Ketorolac and Pregabalin Effects on breaSt Can...
# 2     Taletrectinib in Previously Treated Metastatic...
# ...

# %%
df.fillna('', inplace=True)

# %%
type(df['ZIP_STR'].iloc[5])
# Out:
# str

# %%
df['ZIP_STR'].head(10)
# Out:
# 0    49933 33076 14076 63011 21079 59020 69373 1327...
# 1                                                 1170
# 2                                          33331 44195
# 3                                               SE19RT
# 4                                           60077-1384
# 5
# 6                                                55905
# 7                                          92210 92210
# 8                                                94063
# 9                                               450008
# Name: ZIP_STR, dtype: object

# %%
def contains_number(row, number):
    return number in row.split()

# %%
nct_list = list(df[df['ZIP_STR'].apply(lambda x: contains_number(x, '60601'))]['NCT_NUMBER'])

# %%
nct_list
# Out:
# ['NCT04821141', 'NCT05615753']

# %%
list1 = ['60918', '46524', '60924', '61047', '60962', '60973', '61063', '49061', '49065', '61326', '47929', '49067', '46975', '61337', '61054', '53069', '61377', '46507', '53092', '61321', '61775', '53538', '53066', '47926', '46950', '61024', '46526', '53097', '53137', '61740', '61021', '49055', '61335', '53022', '53017', '47921', '46539', '47997', '61358', '47971', '60952', '46553', '46528', '49071', '47923', '47917', '61349', '53549', '61726', '53576', '61336', '53033', '46542', '60948', '61327', '61039', '53012', '61773', '53534', '60942', '49423', '61019', '49419', '61067', '46508', '53024', '61369', '61731', '60960', '53076']
list2 = ['12345', '67890', '60918']

# %%
not set(list1).isdisjoint(set(list2))
# Out:
# True

# %%
def has_overlap(list1, list2):
    # Convert lists to sets
    set1 = set(list1)
    set2 = set(list2)
    
    # Check for intersection
    return not set1.isdisjoint(set2)

# Example lists
list1 = ['60918', '46524', '60924', '61047', '60962', '60973', '61063', '49061', '49065', '61326', '47929', '49067', '46975', '61337', '61054', '53069', '61377', '46507', '53092', '61321', '61775', '53538', '53066', '47926', '46950', '61024', '46526', '53097', '53137', '61740', '61021', '49055', '61335', '53022', '53017', '47921', '46539', '47997', '61358', '47971', '60952', '46553', '46528', '49071', '47923', '47917', '61349', '53549', '61726', '53576', '61336', '53033', '46542', '60948', '61327', '61039', '53012', '61773', '53534', '60942', '49423', '61019', '49419', '61067', '46508', '53024', '61369', '61731', '60960', '53076']
list2 = ['12345', '67890', '60918']  # Example with overlap

# Check for overlap
print(has_overlap(list1, list2))  # Output: True
# Out:
# True

# %%
closest_zips = ['60601', '60611', '60602', '60603', '60604', '60654', '60606', '60661', '60605', '60610', '60642', '60607', '60614', '60622', '60616', '60612', '60608', '60657', '60647', '60653', '60613', '60609', '60699', '60701', '60624', '60618', '60623', '60640', '60651', '60615', '60625', '60660', '60632', '60644', '60639', '60804', '60621', '60637', '60641', '60636', '60659', '60302', '60626', '60304', '60629', '60645', '60630', '60301', '60649', '60402', '60712', '60305', '60646', '60707', '60130', '60619', '60706', '60620', '60634', '60546', '60652', '60202', '60638', '60171', '60076', '60534', '60153', '60631', '60077', '60656', '60155', '60203', '60201', '60617', '60160', '60456', '60805', '60513', '60459', '60501', '60714', '60104', '60131', '60053', '60643', '60165', '60091', '60176', '60526', '60154', '60628', '60162', '60068', '60453', '60525', '60655', '60455', '60458', '60043', '60164', '46320', '60163', '60415', '60457', '60558', '60093', '60025', '60633', '60803', '60126', '60026', '60521', '46394', '60406', '60482', '60106', '60465', '60827', '60018', '60480', '60523', '60472', '60016', '60022', '60181', '60463', '60469', '60418', '60514', '60419', '46327', '60527',

# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# ...

# %%
df['LOCATIONS'] = df.LOCATIONS.apply(lambda loc_obj: [obj for obj in eval(loc_obj) if obj['Location Country'] == 'United States'])

# %%
df = df[df['LOCATIONS'].apply(lambda x: x != [])]

# %%
df
# Out:
#       Unnamed: 0.1  Unnamed: 0   NCT_NUMBER  \
# 2                2           2  NCT06214793
# 4                4           4  NCT05935384
# 6                6           6  NCT04703244
# 8                8           8  NCT05059444
# 10              10          10  NCT05636943
# ...            ...         ...          ...
# 2519          2519        2519  NCT02772367
# 2521          2521        2521  NCT02735746
# 2523          2523        2523  NCT05952557
# 2524          2524        2524  NCT06327490
# 2525          2525        2525  NCT04314401
#
#                                             STUDY_TITLE  \
# 2     Taletrectinib in Previously Treated Metastatic...
# 4     SIBYL: obServation of Therapy Response With lI...
# 6     Development of Patient Derived Xenografts (PDX...
# 8     ORACLE: Observation of ResiduAl Cancer With Li...
# 10             Couples' QOL in Metastatic Breast Cancer
# ...                                                 ...
# ...

# %%
df['ZIP_STR'] = df.LOCATIONS.apply(lambda x: get_zip_list(x))
df['ZIP_STR']
# Out:
# /var/folders/zl/d2k6s23d1_v34c607q2lvkzr0000gn/T/ipykernel_73669/625081449.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZIP_STR'] = df.LOCATIONS.apply(lambda x: get_zip_list(x))
# 2                                             33331 44195
# 4                                              60077-1384
# 6                                                   55905
# 8                                                   94063
# 10                                                  19111
#                               ...
# 2519                                                10065
# 2521                                                90048
# 2523    72703 91010 92708 94904 92618 92093 90017 9394...
# ...

# %%
def filter_zip_codes(location_list, zip_codes):
    return [location for location in location_list if location["Location Zip"] in zip_codes]

# %%
df['LOCATIONS'].apply(lambda x: filter_zip_codes(x, ["93105", "86401", "81008"]))
# Out:
# 2                                                      []
# 4                                                      []
# 6                                                      []
# 8                                                      []
# 10                                                     []
#                               ...
# 2519                                                   []
# 2521                                                   []
# 2523                                                   []
# 2524                                                   []
# 2525    [{'Location Facility': 'Kingman Regional Medic...
# Name: LOCATIONS, Length: 909, dtype: object

# %%
df.to_csv('../ct_csv/CT_CSV_23_05_ONLYUS_ZIPSTR.csv')

# %%
df = pd.read_csv('../ct_csv/CT_CSV_23_05_ONLYUS_ZIPSTR.csv')

# %%
df.BIOMARKERS = df.BIOMARKERS.apply(lambda x: x.split(',') if isinstance(x, str) else [])

# %%
df
# Out:
#      Unnamed: 0.1  Unnamed: 0   NCT_NUMBER  \
# 0               0           0  NCT06214793
# 1               1           1  NCT05935384
# 2               2           2  NCT04703244
# 3               3           3  NCT05059444
# 4               4           4  NCT05636943
# ..            ...         ...          ...
# 904           904         904  NCT02772367
# 905           905         905  NCT02735746
# 906           906         906  NCT05952557
# 907           907         907  NCT06327490
# 908           908         908  NCT04314401
#
#                                            STUDY_TITLE  \
# 0    Taletrectinib in Previously Treated Metastatic...
# 1    SIBYL: obServation of Therapy Response With lI...
# 2    Development of Patient Derived Xenografts (PDX...
# 3    ORACLE: Observation of ResiduAl Cancer With Li...
# 4             Couples' QOL in Metastatic Breast Cancer
# ..                                                 ...
# ...
